# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a592042f-8416-4152-b43d-826209bb16b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a592042f-8416-4152-b43d-826209bb16b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Loading the dataset
import pandas as pd
df=pd.read_csv("loan-train.csv")
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Getting the dimensionality of the dataset
print(df.shape)
# Out:
# (614, 13)

# %%
df1=df.head(20)
df1
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
# Getting statistical data interpretation of all the columns
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df[['ApplicantIncome','CoapplicantIncome','LoanAmount']].describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  592.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   85.587325
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.000000
# 50%        3812.500000        1188.500000  128.000000
# 75%        5795.000000        2297.250000  168.000000
# max       81000.000000       41667.000000  700.000000

# %%
# DATA CLEANING

# %%
# Finding any null values are there are not
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
# Checking whether atleast any one null value is present in the dataset or not.
df.isnull().values.any()
# Out:
# True

# %%
# Classifying the data into correct and loan approval according to their loan status.
ash=df[df['Loan_Status']=='Y']
valid=df[df['Loan_Status']=='N']
print(len(ash))
print(len(valid))
print(ash)
print(valid)
# Out:
# 422
# 192
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#outliers
outlierfraction=len(ash)/len(valid)
print(outlierfraction)
# Out:
# 2.1979166666666665

# %%
# Getting the details of the loan amount
print("Loan amount details:")
print(ash.LoanAmount.describe())
print(ash.mean())
# Out:
# Loan amount details:
# count    411.000000
# mean     144.294404
# std       85.484607
# min       17.000000
# 25%      100.000000
# 50%      126.000000
# 75%      161.000000
# max      700.000000
# Name: LoanAmount, dtype: float64
# ApplicantIncome      5384.068720
# CoapplicantIncome    1504.516398
# LoanAmount            144.294404
# Loan_Amount_Term      341.072464
# Credit_History          0.981818
# dtype: float64
# <ipython-input-13-54c0d4e88bdd>:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(ash.mean())

# %%
# From the above data, we can interprete that count=411 which means loan amount is very less. The minimum 
#loan amount is 17 and maximum laon amount 700

# %%
print("valid amount details:")
print(valid.LoanAmount.describe())
print(valid.mean())
# Out:
# valid amount details:
# count    181.000000
# mean     151.220994
# std       85.862783
# min        9.000000
# 25%      100.000000
# 50%      129.000000
# 75%      176.000000
# max      570.000000
# Name: LoanAmount, dtype: float64
# ApplicantIncome      5446.078125
# CoapplicantIncome    1877.807292
# LoanAmount            151.220994
# Loan_Amount_Term      344.064516
# Credit_History          0.541899
# dtype: float64
# <ipython-input-14-b7583ffcf9f8>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(valid.mean())

# %%
# From the above data, we can interprete that count=411 which means number of loan given is very high. The minimum
# valid amount is 9 and maximum loan amount is 570

# %%
# Calculate spread (standard deviation) for each class
std1=ash.std()
print(std1)
# Out:
# ApplicantIncome      5765.441615
# CoapplicantIncome    1924.754855
# LoanAmount             85.484607
# Loan_Amount_Term       63.247770
# Credit_History          0.133782
# dtype: float64
# <ipython-input-15-949c6a03de1b>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std1=ash.std()

# %%
#Calculate spread (standard deviation) for each class
std2=valid.std()
print(std2)
# Out:
# ApplicantIncome      6819.558528
# CoapplicantIncome    4384.060103
# LoanAmount             85.862783
# Loan_Amount_Term       69.238921
# Credit_History          0.499639
# dtype: float64
# <ipython-input-16-53f34e4eb24a>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std2=valid.std()

# %%
print("mean of loan amount is",np.mean(data))
print("variance of loan amount is",np.var(data))
# Out:
# mean of loan amount is LoanAmount    146.412162
# dtype: float64
# variance of loan amount is LoanAmount    7312.816609
# dtype: float64

# %%
import numpy as np
import pandas as pd
# Store the real mean in a separate variable
real_mean = round(df['LoanAmount'].mean(),3)
print(real_mean)
# Out:
# 141.166
