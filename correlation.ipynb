# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/machine learning/ML_FDS PROJECT/loan-train.csv')

df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
sns.heatmap(df.corr() ,cmap='cubehelix_r')

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-12-f0f86bb9996e>:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_75e73_row0_col0, #T_75e73_row1_col1, #T_75e73_row2_col2, #T_75e73_row3_col3, #T_75e73_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_75e73_row0_col1, #T_75e73_row0_col4, #T_75e73_row1_col0, #T_75e73_row1_col3, #T_75e73_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_75e73_row0_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_75e73_row0_col3, #T_75e73_row1_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_75e73_row1_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_75e73_row2_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_75e73_row2_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_75e73_row2_col3, #T_75e73_row4_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_75e73_row2_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_75e73_row3_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_75e73_row3_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_75e73_row3_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_75e73_row3_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_75e73_row4_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_75e73_row4_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75e73_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ApplicantIncome</th>
#       <th class="col_heading level0 col1" >CoapplicantIncome</th>
#       <th class="col_heading level0 col2" >LoanAmount</th>
#       <th class="col_heading level0 col3" >Loan_Amount_Term</th>
#       <th class="col_heading level0 col4" >Credit_History</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75e73_level0_row0" class="row_heading level0 row0" >ApplicantIncome</th>
#       <td id="T_75e73_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_75e73_row0_col1" class="data row0 col1" >-0.12</td>
#       <td id="T_75e73_row0_col2" class="data row0 col2" >0.57</td>
#       <td id="T_75e73_row0_col3" class="data row0 col3" >-0.05</td>
#       <td id="T_75e73_row0_col4" class="data row0 col4" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_75e73_level0_row1" class="row_heading level0 row1" >CoapplicantIncome</th>
#       <td id="T_75e73_row1_col0" class="data row1 col0" >-0.12</td>
#       <td id="T_75e73_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_75e73_row1_col2" class="data row1 col2" >0.19</td>
#       <td id="T_75e73_row1_col3" class="data row1 col3" >-0.06</td>
#       <td id="T_75e73_row1_col4" class="data row1 col4" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_75e73_level0_row2" class="row_heading level0 row2" >LoanAmount</th>
#       <td id="T_75e73_row2_col0" class="data row2 col0" >0.57</td>
#       <td id="T_75e73_row2_col1" class="data row2 col1" >0.19</td>
#       <td id="T_75e73_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_75e73_row2_col3" class="data row2 col3" >0.04</td>
#       <td id="T_75e73_row2_col4" class="data row2 col4" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_75e73_level0_row3" class="row_heading level0 row3" >Loan_Amount_Term</th>
#       <td id="T_75e73_row3_col0" class="data row3 col0" >-0.05</td>
#       <td id="T_75e73_row3_col1" class="data row3 col1" >-0.06</td>
#       <td id="T_75e73_row3_col2" class="data row3 col2" >0.04</td>
#       <td id="T_75e73_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_75e73_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_75e73_level0_row4" class="row_heading level0 row4" >Credit_History</th>
#       <td id="T_75e73_row4_col0" class="data row4 col0" >-0.01</td>
#       <td id="T_75e73_row4_col1" class="data row4 col1" >-0.00</td>
#       <td id="T_75e73_row4_col2" class="data row4 col2" >-0.01</td>
#       <td id="T_75e73_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_75e73_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>
